# %%
# Juego de Preguntas y Respuestas ---> Geografía

# %%
# El juego sigue hasta que el jugador responda incorrectamente 3 de veces o haya respondido 5 preguntas correctamente.

# Comienza creando un diccionario que contenga preguntas de geografía como claves y respuestas como valores.

# Implementa una función para seleccionar una pregunta aleatoria del diccionario.

# Utiliza un bucle `while` para hacer preguntas de geografía hasta que el jugador responda un número específico de preguntas correctamente o alcance un número máximo de respuestas incorrectas.

# Dentro del bucle, presenta la pregunta al jugador y permita que ingresen sus respuestas.

# Lleva un seguimiento del número de preguntas realizadas y el número de respuestas correctas.

# Determina las condiciones de victoria y derrota del juego y sal del bucle cuando se cumplan estas condiciones

# Definimos las preguntas y respuestas con un diccionario

# %%
#JUEGO PREGUNTAS Y RESPUESTAS
# Definimos las preguntas y respuestas con un diccionario

preguntas_geografía={"¿Cuál es la montaña más alta de España?": "Teide",
                    "¿El mar muerto es realmente un mar?":"No",
                    "¿Qué continente es el más poblado?":"Asia",
                    "¿Qué río pasa por más países?":"Danubio",
                    "¿Cuál es el país más pequeño del mundo?":"Ciudad del Vaticano",
                    "¿Cuántos océanos hay en la Tierra? (Inserta un número)" : "5",
                    "¿Qué río pasa por París?" : "Sena",
                    "¿Cuál es el río más largo de España?" : "Tajo",
                    "¿Qué ocupa más superficie, el agua o los continentes? (Escribe 'el agua' o 'los continentes'" : "El agua",
                    "¿Cuál es el continente más seco del planeta?": "Antártida",
                    "¿Cuál es la isla más grande del mundo?" : "Groenlandia",
                    "¿Cual es la capital de Argentina?" : "Buenos Aires"}

#Importamos la librería random para que podamos dar resultados aleatorios más adelante:
import random

# Iniciamos juego dando la bienvenida y explicando las reglas del juego.
print("WELCOME! En este juego de preguntas y respuestas de geografía, pondrás a prueba tus conocimientos. \n\n ¡Piensa bien cada respuesta! La partida terminará cuando alcances 3 fallos. \n Para ganar, deberás acertar 5 preguntas. \n Fácil, ¿no? \n")
print("*"*60)
print("¿Estás preparado/a?")
start = input("Pulsa cualquier letra para empezar a jugar.")
pass
print("START")
print("*"*30)

# Creamos una funcion para seleccionar y ofrecer a la persona usuaria una pregunta aleatoria de nuestro diccionario, sin que esta se repita.
def juego():

#Convertimos las keys en una lista para poder seleccionar solo las claves.
    preguntas = list(preguntas_geografía.keys()) 
    preguntas_hechas = []

# Creamos dos variables que nos servirán para contar las respuestas correctas y los fallos por partida. 
    respuestas_correctas=0
    fallos=0

   
    while len(preguntas_hechas) <= len(preguntas_geografía):
            pregunta_aleatoria= random.choice(preguntas)
            respuesta_usuario= input(pregunta_aleatoria).lower()


            if pregunta_aleatoria not in preguntas_hechas:
                preguntas_hechas.append(pregunta_aleatoria)
                respuestas = preguntas_geografía[pregunta_aleatoria]
                preguntas.remove(pregunta_aleatoria)
            
                if respuesta_usuario == respuestas.lower():
                    print(f"Tu respuesta es {respuesta_usuario}")
                    print("¡Has acertado! \n")
                    print("<3"*40)
                    respuestas_correctas += 1

                    if respuestas_correctas == 5:
                        print("\n")
                        print("*"*60)
                        print("ENHORABUENA \n ¡¡HAS GANADO EL JUEGO!!")
                        break

                else:
                    fallos += 1
                    print(f"Tu respuesta es {respuesta_usuario}")
                    print("¡Ups! Has fallado. Esa no es la respuesta correcta.\n") 
                    print("-"*60) 

                    if fallos==3:
                        print("\n")
                        print("*"*60)
                        print("¡GAME OVER! \n HAS FALLADO 3 VECES.\n\n\n\n")
                        break

            else:
                print("No quedan más preguntas en el juego!")
                break

    return juego

play = juego()
print(play)

#Comenzamos el cuerpo del juego. Creamos un bucle para que la consola haga preguntas a la persona usuaria hasta que esta gane o pierda.


#Ahora creamos variables para: 1) Tener la respuesta correcta, o values del diccionario, y 2 que la persona usuaria pueda escribir sus respuestas en relación a cada pregunta.    
    
    
#Creamos condicionales en caso de acertar y ganar, o fallar y perder, con el break para salir del bucle una vez la persona usuaria alcance el límite.
# Out:
# WELCOME! En este juego de preguntas y respuestas de geografía, pondrás a prueba tus conocimientos.
#
#  ¡Piensa bien cada respuesta! La partida terminará cuando alcances 3 fallos.
#  Para ganar, deberás acertar 5 preguntas.
#  Fácil, ¿no?
#
# ************************************************************
# ¿Estás preparado/a?
# START
# ******************************
# Tu respuesta es senaç
# ¡Ups! Has fallado. Esa no es la respuesta correcta.
#
# ------------------------------------------------------------
# Tu respuesta es dsa
# ¡Ups! Has fallado. Esa no es la respuesta correcta.
#
# ------------------------------------------------------------
# Tu respuesta es sena
# ¡Ups! Has fallado. Esa no es la respuesta correcta.
#
# ------------------------------------------------------------
#
#
# ************************************************************
# ¡GAME OVER!
#  HAS FALLADO 3 VECES.
#
#
#
#
# <function juego at 0x000001CC0875F920>
